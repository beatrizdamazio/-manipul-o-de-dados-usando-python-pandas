# %% [markdown]
# <a href="https://colab.research.google.com/github/beatrizdamazio/-manipul-o-de-dados-usando-python-pandas/blob/main/Primeiro_Exemplo_Em_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Primeiro exemplo de manipulação de dados usando python pandas**
#
# Professor: Henrique Poya
#
# Aluna: Beatriz D. Soares
#
# Data: 6 de fevereiro de 2023

# %%
#1) Para instalar, use este comando
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#2) Importanto biblioteca pandas no python
import pandas as pd
combustiveis_df = pd.read_excel("ca-2021-02.xlsx")

# %%
#3) Ver o dataframe
print (combustiveis_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
#4) Ver o database tabeladinho bonitinho
display (combustiveis_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
#5) Exibir as primeiras 5 linhas
display(combustiveis_df.head())
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# ...

# %%
#6) Exibir as primeiras 15 linhas
display (combustiveis_df.head(15))
# Out:
#    Regiao - Sigla Estado - Sigla        Municipio  \
# 0              NE             AL        ARAPIRACA
# 1              NE             AL        ARAPIRACA
# 2              NE             AL        ARAPIRACA
# 3              NE             AL        ARAPIRACA
# 4              NE             AL        ARAPIRACA
# 5              NE             AL  DELMIRO GOUVEIA
# 6              NE             AL  DELMIRO GOUVEIA
# 7              NE             AL  DELMIRO GOUVEIA
# 8              NE             AL  DELMIRO GOUVEIA
# 9              NE             AL  DELMIRO GOUVEIA
# 10             NE             AL  DELMIRO GOUVEIA
# 11             NE             AL  DELMIRO GOUVEIA
# 12             NE             AL  DELMIRO GOUVEIA
# 13             NE             AL  DELMIRO GOUVEIA
# 14             NE             AL  DELMIRO GOUVEIA
#
#                                   Revenda      CNPJ da Revenda  \
# 0                    POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
#7) Mostrar quantas linhas e colunas tem
print (combustiveis_df.shape)
# Out:
# (168409, 16)

# %%
#8) Mostrar as estatisticas basicas ()
print (combustiveis_df.describe)
# Out:
# <bound method NDFrame.describe of        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
#9) Mostrar quais são as colunas e que tipo de dados cada um tem
print(combustiveis_df.info)
# Out:
# <bound method DataFrame.info of        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
#10) Filtrar por apenas uma coluna
display (combustiveis_df['Revenda'])
# Out:
# 0                               POSTO ARAPIRACA LTDA
# 1                               POSTO ARAPIRACA LTDA
# 2                               POSTO ARAPIRACA LTDA
# 3                               POSTO ARAPIRACA LTDA
# 4                               POSTO ARAPIRACA LTDA
#                              ...
# 168404    COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA
# 168405             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168406             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168407             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168408             ABC DISTRIBUICAO DE PETROLEO LTDA
# Name: Revenda, Length: 168409, dtype: object

# %%
#11) Para filtrar por mais de uma coluna, criar um novo dataframe apenas com as colunas desejadas
ca_df = combustiveis_df[['Revenda', 'Municipio', 'Valor de Venda']] 
display(ca_df)
# Out:
#                                            Revenda  Municipio  Valor de Venda
# 0                             POSTO ARAPIRACA LTDA  ARAPIRACA           6.799
# 1                             POSTO ARAPIRACA LTDA  ARAPIRACA           5.299
# 2                             POSTO ARAPIRACA LTDA  ARAPIRACA           5.549
# 3                             POSTO ARAPIRACA LTDA  ARAPIRACA           6.899
# 4                             POSTO ARAPIRACA LTDA  ARAPIRACA           5.649
# ...                                            ...        ...             ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA     JEQUIE           5.859
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA           6.580
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA           4.740
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA           5.448
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA           6.580
#
# [168409 rows x 3 columns]

# %%
#12) Para adicionar colunas ao dataframe criado, basta inserir.
ca_df = combustiveis_df[['Revenda', 'Municipio', 'Produto','Valor de Venda']] 
display(ca_df)
# Out:
#                                            Revenda  Municipio  \
# 0                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 1                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 2                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 3                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 4                             POSTO ARAPIRACA LTDA  ARAPIRACA
# ...                                            ...        ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA     JEQUIE
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
#
#                    Produto  Valor de Venda
# 0                 GASOLINA           6.799
# 1                   ETANOL           5.299
# 2                   DIESEL           5.549
# 3       GASOLINA ADITIVADA           6.899
# ...

# %%
#13) Mostrar uma linha em específico
display(ca_df.loc[3])
# Out:
# Revenda           POSTO ARAPIRACA LTDA
# Municipio                    ARAPIRACA
# Produto             GASOLINA ADITIVADA
# Valor de Venda                   6.899
# Name: 3, dtype: object

# %%
#14) Mostrar um intervalo de linhas
display(ca_df.loc[9:19])
# Out:
#                                   Revenda        Municipio  \
# 9          AUTO POSTO FREITAS & MAIA LTDA  DELMIRO GOUVEIA
# 10               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 11               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 12               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 13               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 14  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 15  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 16  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 17  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 18  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 19         MARCOS ANTONIO DA SILVA CABRAL      ITACOATIARA
#
#                Produto  Valor de Venda
# 9           DIESEL S10           5.983
# 10            GASOLINA           7.197
# 11              ETANOL           5.987
# 12              DIESEL           5.978
# 13          DIESEL S10           5.989
# ...

# %% [markdown]
# # **Atividades**
#
# 1)a) Criar um dataframe gas_df contendo apenas as quatro colunas (Revenda, Municipio, Produto, Valor de venda) somente com combustivel GASOLINA.

# %%
gas_df = ca_df.loc[ca_df['Produto']=='GASOLINA']
display(gas_df)
# Out:
#                                                   Revenda  \
# 0                                    POSTO ARAPIRACA LTDA
# 5                          AUTO POSTO FREITAS & MAIA LTDA
# 10                               AUTO POSTO DA PEDRA LTDA
# 14                  COMERCIO DE COMBUSTIVEIS NENZITA LTDA
# 19                         MARCOS ANTONIO DA SILVA CABRAL
# ...                                                   ...
# 168392                           AUTO POSTO KM BAURU LTDA
# 168394      COOPERCITRUS COOPERATIVA DE PRODUTORES RURAIS
# 168399  VICMAR COMERCIO DE COMBUSTIVEIS E LUBRIFICANTE...
# 168403         COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA
# 168405                  ABC DISTRIBUICAO DE PETROLEO LTDA
#
#                     Municipio   Produto  Valor de Venda
# 0                   ARAPIRACA  GASOLINA           6.799
# 5             DELMIRO GOUVEIA  GASOLINA           7.198
# 10            DELMIRO GOUVEIA  GASOLINA           7.197
# ...

# %% [markdown]
# b) Mostrar qual é o posto e municipio com gasolina mais cara do pais

# %%
display(gas_df[['Revenda', 'Municipio', 'Valor de Venda']].max())
# Out:
# Revenda           ZV POSTO DE SERVIÇO LTDA.
# Municipio                           XANXERE
# Valor de Venda                        7.999
# dtype: object

# %% [markdown]
# 2) Em um DataFrame.loc[] com múltiplas condições para filtragem, indique:
#
# a)Quais são os preços e postos que vendem ETANOL na minha cidade (INDAIATUBA) ordenado do menor valor de venda para o maior.

# %%
etaind_df = combustiveis_df.loc[(ca_df['Produto'] == 'ETANOL') & (ca_df['Municipio'] == 'INDAIATUBA')]
etaind_df.sort_values(by='Valor de Venda', inplace=True)
display(etaind_df)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#        Regiao - Sigla Estado - Sigla   Municipio  \
# 160592             SE             SP  INDAIATUBA
# 140194             SE             SP  INDAIATUBA
# 140661             SE             SP  INDAIATUBA
# 159497             SE             SP  INDAIATUBA
# 141167             SE             SP  INDAIATUBA
# ...               ...            ...         ...
# 51129              SE             SP  INDAIATUBA
# 51138              SE             SP  INDAIATUBA
# 84395              SE             SP  INDAIATUBA
# 65878              SE             SP  INDAIATUBA
# 65363              SE             SP  INDAIATUBA
#
# ...

# %% [markdown]
# 3)Qual a média de preços dos combustíveis GASOLINA e GASOLINA ADITIVADA do Bairro MOOCA em SÃO PAULO?

# %%
display(combustiveis_df.loc[(combustiveis_df['Bairro'] == 'MOOCA') & 
                            (combustiveis_df['Municipio'] == 'SAO PAULO') & 
                            (combustiveis_df['Produto'].isin(["GASOLINA", "GASOLINA ADITIVADA"])), 
                            ['Valor de Venda']].mean())
# Out:
# Valor de Venda    6.575596
# dtype: float64

# %% [markdown]
# 4) Como mostrar média de valor de venda POR COMBUSTÍVEL no Brasil todo?

# %%
media_por_combustivel_df = ca_df[['Produto', 'Valor de Venda']].groupby(by='Produto').mean().round(2)
display(media_por_combustivel_df)
# Out:
#                     Valor de Venda
# Produto
# DIESEL                        5.38
# DIESEL S10                    5.45
# ETANOL                        5.46
# GASOLINA                      6.71
# GASOLINA ADITIVADA            6.86
# GNV                           4.39

# %%
#Quero adicionar uma coluna de valor booleano no combustiveis_df
# chamada "Ativo" que, por padrão, vai ser True para 
# TODAS as linhas
combustiveis_df['Ativo'] = True
print(combustiveis_df.info())
display(combustiveis_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168409 entries, 0 to 168408
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     168409 non-null  object
#  1   Estado - Sigla     168409 non-null  object
#  2   Municipio          168409 non-null  object
#  3   Revenda            168409 non-null  object
#  4   CNPJ da Revenda    168409 non-null  object
#  5   Nome da Rua        168409 non-null  object
#  6   Numero Rua         168353 non-null  object
#  7   Complemento        35057 non-null   object
#  8   Bairro             168043 non-null  object
#  9   Cep                168409 non-null  object
#  10  Produto            168409 non-null  object
#  11  Data da Coleta     168409 non-null  datetime64[ns]
#  12  Valor de Venda     168409 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  168409 non-null  object
# ...

# %%
# E se eu quiser uma coluna nova chamada "Obs"
# que preencha automaticamente "MELHOR CIDADE"
# quando o Município for INDAIATUBA, SP...
#combustiveis_df['Obs'] = "MELHOR CIDADE" if combustiveis_df['Municipio'] == "INDAIATUBA" else ""
#amanhã a solução

# %%
# Exportar para Excel o dataframe com etanol em Indaiatuba....
etanol_indaiatuba_df.to_excel('etanol_indaiatuba.xlsx', sheet_name='Etanol em Indaiatuba')
